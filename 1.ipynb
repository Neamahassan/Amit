# %%
print("hello\b")
# Out:
# hell

# %%
print("hello\nworld")
# Out:
# hello
# world

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print("this is a double quote: \"hello\" ")
# Out:
# this is a double quote: "hello"

# %%
name ="amit learning"
print(name.title())
# Out:
# Amit Learning

# %%
name ="amit learning amit machine"
print(name.endswith("machine"))
# Out:
# True

# %%
name ="amit learning amit machine"
print(name.startswith("hello"))
# Out:
# False

# %%
words = ["this "," is", " a",  "sentence."]
sentence = ''.join(words)
print(sentence)
# Out:
# this  is asentence.

# %%
name ="amit learning amit machine"
print(name.split())
# Out:
# ['amit', 'learning', 'amit', 'machine']

# %%
name ="amit learning amit machine"
print(name.count("amit"))
# Out:
# 2

# %%
name ="amit learning"
print(name.swapcase())
# Out:
# AMIT LEARNING

# %%
name ="amit learning"
print(name.capitalize())
# Out:
# Amit learning

# %%
name ="amit learning"
print(name.upper())
# Out:
# AMIT LEARNING

# %%
name = "AMIT LEARNING"
print(name.replace("AMIT "," hello "))
# Out:
#  hello LEARNING

# %%
name = "AMIT LEARNING"
print(name.lower())
# Out:
# amit learning

# %%
name ="amit learning"
print(name[0:4:1])
# Out:
# amit

# %%
name ="amit learning"
print(name[0])
# Out:
# a

# %%
x = 5.5
print(type(x))

# %%
x = (1,2,3,4,"amit",True)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = {1,2,3,4,"amit",True}
print(type(x))
# Out:
# <class 'set'>

# %%
x = {"key1": "value1", "key2":"value2"}
print(type(x))
# Out:
# <class 'dict'>

# %%
name = "amit learning"
print(name[0])
# Out:
# a

# %%
name = "amit learning"
print(name[0])

# %%
x = [1,2,3,4,"amit",True]
print(type(x))
# Out:
# <class 'list'>

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
x = 5.5
print(type(x))
# Out:
# <class 'float'>

# %%
x = 5
print(type(x))

# %%
your_name = "amit learning"
your_age = 24
course_name = "machine learning ang AI diploma"
output_text = f"my name is {your_name}, and l am {your_age} years old. l am engaged in learning {course_name}."
print(output_text)
# Out:
# my name is amit learning, and l am 24 years old. l am engaged in learning machine learning ang AI diploma.

# %%
print("my name is{0} ,my age is {1}".format(" amit",  24))
# Out:
# my name is amit ,my age is 24

# %%
print("my name is{0},my age is {1}".format(" amit",  24))
# Out:
# my name is amit,my age is 24

# %%
print("my name is{0},my age is{1}".format(" amit" ,24))
# Out:
# my name is amit,my age is24

# %%
def process_email(email):
    if email.count("@") != 1:
        return "Invalid email"
    
    at_index = email.find("@")
    domain_part = email[at_index:]
    
    if domain_part.count(".") < 1:
        return "Invalid email"
    
    username = email[:at_index]
    
    last_dot_index = email.rfind(".")
    domain = email[at_index + 1 : last_dot_index]
    
    if email.endswith(".com"):
        domain_type = "Commercial Domain"
    elif email.endswith(".edu"):
        domain_type = "Educational Domain"
    else:
        domain_type = "Other Domain"
    
    return username, domain, domain_type


email = input("Enter your email: ")
result = process_email(email)

if result == "Invalid email":
    print(result)
else:
    username, domain, domain_type = result
    print("Username:", username)
    print("Domain:", domain)
    print("Domain Type:", domain_type)
