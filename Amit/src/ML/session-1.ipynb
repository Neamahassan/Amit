# %%
from sklearn import

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.9 MB 2.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/8.9 MB 1.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/8.9 MB 2.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/8.9 MB 2.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/8.9 MB 2.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.4/8.9 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.1/8.9 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.9 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/8.9 MB 2.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.2/8.9 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 6.0/8.9 MB 2.5 MB/s eta 0:00:02
# ...
