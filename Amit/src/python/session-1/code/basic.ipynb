# %%
def info_user(name: str, age: int) -> str:
    """This function will return the name and age of the user.

    Args:
        name (str): name of the user
        age (int): age of the user

    Returns:
        str: name and age of the user
    """
    return f"my name is {name} and i am {age} years old"

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 info_user(age =24, name="george")
#
# NameError: name 'info_user' is not defined

# %%
def func(item, lst[])
    lst.append(iteam)
  reture lst
    print(func(""))
# Out:
#   Cell In[3], line 1
#     def func(item, lst[])
#                       ^
# SyntaxError: invalid syntax

# %%
def func(item, lsف= None): 
    if lst is None:
        lst = []
    lst.append(item)
    return lst

# %%
def sum (x):
    return  x= 10
print(sum)

# %%
sam_l = lambdax x: x+10
type(em_l)

# %%
def function_1(n):
    return lambda a : a*n
function_2 = function_1(2)
print( function_2(11))

# %%
print("hello world for \"students")
# Out:
# hello world for "students

# %%
name = "depi for machine learning and depi for genai"
name.endswith()
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 name = "depi for machine learning and depi for genai"
#       2 name.endswith("depi")
# ----> 3 type(x)
#
# NameError: name 'x' is not defined

# %%
new_x =''.join(x)

# %%
name = "depi for machine learning and depi for genai"
name.split()
type(x)
# Out:
# str

# %%
name = "depi for machine learning and depi for genai"

name.count("depi")
# Out:
# 2

# %%
name = "Depi for machine learning"
name.title()
# Out:
# 'Depi For Machine Learning'

# %%
name = "Depi for machine learning"
name.capitalize()
# Out:
# 'Depi for machine learning'

# %%
name = "Depi for machine learning"
name.replace("dapi","machine")
# Out:
# 'Depi for machine learning'

# %%
name = "Depi for machine learning"
capital = name.upper()
capital.lower()
# Out:
# DEPI FOR MACHINE LEARNING

# %%
x = "depi for machine learning"
print(x[:])
type(x)
# Out:
# depi for machine learning
# str

# %%
lst_1 = [1,2,3,4,5]
print(type(lst_1))
# Out:
# <class 'list'>
